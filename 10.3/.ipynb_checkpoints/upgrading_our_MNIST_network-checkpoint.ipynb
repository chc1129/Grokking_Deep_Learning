# %%
import numpy as np, sys
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255,
                  y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
    
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

np.random.seed(1)
alpha, iterations = (2, 300)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * (input_cols - kernel_cols)) * num_kernels

kernels = \
    0.02 * np.random.random((kernel_rows*kernel_cols, num_kernels)) - 0.01
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

def get_image_section(layer, row_from, row_to, col_from, col_to):
    section = layer[:, row_from:row_to, col_from:col_to]
    return section.reshape(-1, 1, row_to-row_from, col_to-col_from)

for j in range(iterations):
    train_acc = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = ((i * batch_size), ((i+1) * batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        layer_0.shape
        
        sects = list()
        for row_start in range(layer_0.shape[1] - kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start, row_start + kernel_rows,
                                         col_start, col_start + kernel_cols)
                sects.append(sect)
                
        expanded_input = np.concatenate(sects, axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0] * es[1], -1)
        
        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0], -1))
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2))
        
        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == np.argmax(labelset))
            train_acc += _inc
 
        layer_2_delta = \
            (labels[batch_start:batch_end] - layer_2) / batch_size
        layer_1_delta = \
            layer_2_delta.dot(weights_1_2.T) * tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        lld_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(lld_reshape)
        kernels -= alpha * k_update
        
    test_acc = 0
    
    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        layer_0.shape
        
        sects = list()
        for row_start in range(layer_0.shape[1] - kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                          row_start, row_start + kernel_rows,
                                          col_start, col_start + kernel_cols)
                sects.append(sect)
                
        expanded_input = np.concatenate(sects, axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1], -1)
            
        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0], -1))
        layer_2 = np.dot(layer_1, weights_1_2)
            
        test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
    if(j % 1 == 0):
        sys.stdout.write(
            "\n" + \
            "I:" + str(j) + \
            " Train-Acc:" + str(train_acc/float(len(images))) + \
            " Test-Acc:" + str(test_acc/float(len(test_images))))
# Out:
# Using TensorFlow backend.
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\chc11\anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: overflow encountered in exp
# C:\Users\chc11\anaconda3\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# I:0 Train-Acc:0.097 Test-Acc:0.098
# I:1 Train-Acc:0.087 Test-Acc:0.098
# I:2 Train-Acc:0.087 Test-Acc:0.098
# I:3 Train-Acc:0.087 Test-Acc:0.098
# I:4 Train-Acc:0.087 Test-Acc:0.098
# I:5 Train-Acc:0.087 Test-Acc:0.098
# I:6 Train-Acc:0.087 Test-Acc:0.098
# I:7 Train-Acc:0.087 Test-Acc:0.098
# I:8 Train-Acc:0.087 Test-Acc:0.098
# I:9 Train-Acc:0.087 Test-Acc:0.098
# I:10 Train-Acc:0.087 Test-Acc:0.098
# I:11 Train-Acc:0.087 Test-Acc:0.098
# I:12 Train-Acc:0.087 Test-Acc:0.098
# I:13 Train-Acc:0.087 Test-Acc:0.098
# I:14 Train-Acc:0.087 Test-Acc:0.098
# I:15 Train-Acc:0.087 Test-Acc:0.098
# I:16 Train-Acc:0.087 Test-Acc:0.098
# I:17 Train-Acc:0.087 Test-Acc:0.098
# I:18 Train-Acc:0.087 Test-Acc:0.098
# I:19 Train-Acc:0.087 Test-Acc:0.098
# I:20 Train-Acc:0.087 Test-Acc:0.098
# I:21 Train-Acc:0.087 Test-Acc:0.098
# I:22 Train-Acc:0.087 Test-Acc:0.098
# I:23 Train-Acc:0.087 Test-Acc:0.098
# I:24 Train-Acc:0.087 Test-Acc:0.098
# I:25 Train-Acc:0.087 Test-Acc:0.098
# I:26 Train-Acc:0.087 Test-Acc:0.098
# I:27 Train-Acc:0.087 Test-Acc:0.098
# I:28 Train-Acc:0.087 Test-Acc:0.098
# I:29 Train-Acc:0.087 Test-Acc:0.098
# I:30 Train-Acc:0.087 Test-Acc:0.098
# I:31 Train-Acc:0.087 Test-Acc:0.098
# I:32 Train-Acc:0.087 Test-Acc:0.098
# I:33 Train-Acc:0.087 Test-Acc:0.098
# I:34 Train-Acc:0.087 Test-Acc:0.098
# I:35 Train-Acc:0.087 Test-Acc:0.098
# I:36 Train-Acc:0.087 Test-Acc:0.098
# I:37 Train-Acc:0.087 Test-Acc:0.098
# I:38 Train-Acc:0.087 Test-Acc:0.098
# I:39 Train-Acc:0.087 Test-Acc:0.098
# I:40 Train-Acc:0.087 Test-Acc:0.098
# I:41 Train-Acc:0.087 Test-Acc:0.098
# I:42 Train-Acc:0.087 Test-Acc:0.098
# I:43 Train-Acc:0.087 Test-Acc:0.098
# I:44 Train-Acc:0.087 Test-Acc:0.098
# I:45 Train-Acc:0.087 Test-Acc:0.098
# I:46 Train-Acc:0.087 Test-Acc:0.098
# I:47 Train-Acc:0.087 Test-Acc:0.098
# I:48 Train-Acc:0.087 Test-Acc:0.098
# I:49 Train-Acc:0.087 Test-Acc:0.098
# I:50 Train-Acc:0.087 Test-Acc:0.098
# I:51 Train-Acc:0.087 Test-Acc:0.098
# I:52 Train-Acc:0.087 Test-Acc:0.098
# I:53 Train-Acc:0.087 Test-Acc:0.098
# I:54 Train-Acc:0.087 Test-Acc:0.098
# I:55 Train-Acc:0.087 Test-Acc:0.098
# I:56 Train-Acc:0.087 Test-Acc:0.098
# I:57 Train-Acc:0.087 Test-Acc:0.098
# I:58 Train-Acc:0.087 Test-Acc:0.098
# I:59 Train-Acc:0.087 Test-Acc:0.098
# I:60 Train-Acc:0.087 Test-Acc:0.098
# I:61 Train-Acc:0.087 Test-Acc:0.098
# I:62 Train-Acc:0.087 Test-Acc:0.098
# I:63 Train-Acc:0.087 Test-Acc:0.098
# I:64 Train-Acc:0.087 Test-Acc:0.098
# I:65 Train-Acc:0.087 Test-Acc:0.098
# I:66 Train-Acc:0.087 Test-Acc:0.098
# I:67 Train-Acc:0.087 Test-Acc:0.098
# I:68 Train-Acc:0.087 Test-Acc:0.098
# I:69 Train-Acc:0.087 Test-Acc:0.098
# I:70 Train-Acc:0.087 Test-Acc:0.098
# I:71 Train-Acc:0.087 Test-Acc:0.098
# I:72 Train-Acc:0.087 Test-Acc:0.098
# I:73 Train-Acc:0.087 Test-Acc:0.098
# I:74 Train-Acc:0.087 Test-Acc:0.098
# I:75 Train-Acc:0.087 Test-Acc:0.098
# I:76 Train-Acc:0.087 Test-Acc:0.098
# I:77 Train-Acc:0.087 Test-Acc:0.098
# I:78 Train-Acc:0.087 Test-Acc:0.098
# I:79 Train-Acc:0.087 Test-Acc:0.098
# I:80 Train-Acc:0.087 Test-Acc:0.098
# I:81 Train-Acc:0.087 Test-Acc:0.098
# I:82 Train-Acc:0.087 Test-Acc:0.098
# I:83 Train-Acc:0.087 Test-Acc:0.098
# I:84 Train-Acc:0.087 Test-Acc:0.098
# I:85 Train-Acc:0.087 Test-Acc:0.098
# I:86 Train-Acc:0.087 Test-Acc:0.098
# I:87 Train-Acc:0.087 Test-Acc:0.098
# I:88 Train-Acc:0.087 Test-Acc:0.098
# I:89 Train-Acc:0.087 Test-Acc:0.098
# I:90 Train-Acc:0.087 Test-Acc:0.098
# I:91 Train-Acc:0.087 Test-Acc:0.098
# I:92 Train-Acc:0.087 Test-Acc:0.098
# I:93 Train-Acc:0.087 Test-Acc:0.098
# I:94 Train-Acc:0.087 Test-Acc:0.098
# I:95 Train-Acc:0.087 Test-Acc:0.098
# I:96 Train-Acc:0.087 Test-Acc:0.098
# I:97 Train-Acc:0.087 Test-Acc:0.098
# I:98 Train-Acc:0.087 Test-Acc:0.098
# I:99 Train-Acc:0.087 Test-Acc:0.098
# I:100 Train-Acc:0.087 Test-Acc:0.098
# I:101 Train-Acc:0.087 Test-Acc:0.098
# I:102 Train-Acc:0.087 Test-Acc:0.098
# I:103 Train-Acc:0.087 Test-Acc:0.098
# I:104 Train-Acc:0.087 Test-Acc:0.098
# I:105 Train-Acc:0.087 Test-Acc:0.098
# I:106 Train-Acc:0.087 Test-Acc:0.098
# I:107 Train-Acc:0.087 Test-Acc:0.098
# I:108 Train-Acc:0.087 Test-Acc:0.098
# I:109 Train-Acc:0.087 Test-Acc:0.098
# I:110 Train-Acc:0.087 Test-Acc:0.098
# I:111 Train-Acc:0.087 Test-Acc:0.098
# I:112 Train-Acc:0.087 Test-Acc:0.098
# I:113 Train-Acc:0.087 Test-Acc:0.098
# I:114 Train-Acc:0.087 Test-Acc:0.098
# I:115 Train-Acc:0.087 Test-Acc:0.098
# I:116 Train-Acc:0.087 Test-Acc:0.098
# I:117 Train-Acc:0.087 Test-Acc:0.098
# I:118 Train-Acc:0.087 Test-Acc:0.098
# I:119 Train-Acc:0.087 Test-Acc:0.098
# I:120 Train-Acc:0.087 Test-Acc:0.098
# I:121 Train-Acc:0.087 Test-Acc:0.098
# I:122 Train-Acc:0.087 Test-Acc:0.098
# I:123 Train-Acc:0.087 Test-Acc:0.098
# I:124 Train-Acc:0.087 Test-Acc:0.098
# I:125 Train-Acc:0.087 Test-Acc:0.098
# I:126 Train-Acc:0.087 Test-Acc:0.098
# I:127 Train-Acc:0.087 Test-Acc:0.098
# I:128 Train-Acc:0.087 Test-Acc:0.098
# I:129 Train-Acc:0.087 Test-Acc:0.098
# I:130 Train-Acc:0.087 Test-Acc:0.098
# I:131 Train-Acc:0.087 Test-Acc:0.098
# I:132 Train-Acc:0.087 Test-Acc:0.098
# I:133 Train-Acc:0.087 Test-Acc:0.098
# I:134 Train-Acc:0.087 Test-Acc:0.098
# I:135 Train-Acc:0.087 Test-Acc:0.098
# I:136 Train-Acc:0.087 Test-Acc:0.098
# I:137 Train-Acc:0.087 Test-Acc:0.098
# I:138 Train-Acc:0.087 Test-Acc:0.098
# I:139 Train-Acc:0.087 Test-Acc:0.098
# I:140 Train-Acc:0.087 Test-Acc:0.098
# I:141 Train-Acc:0.087 Test-Acc:0.098
# I:142 Train-Acc:0.087 Test-Acc:0.098
# I:143 Train-Acc:0.087 Test-Acc:0.098
# I:144 Train-Acc:0.087 Test-Acc:0.098
# I:145 Train-Acc:0.087 Test-Acc:0.098
# I:146 Train-Acc:0.087 Test-Acc:0.098
# I:147 Train-Acc:0.087 Test-Acc:0.098
# I:148 Train-Acc:0.087 Test-Acc:0.098
# I:149 Train-Acc:0.087 Test-Acc:0.098
# I:150 Train-Acc:0.087 Test-Acc:0.098
# I:151 Train-Acc:0.087 Test-Acc:0.098
# I:152 Train-Acc:0.087 Test-Acc:0.098
# I:153 Train-Acc:0.087 Test-Acc:0.098
# I:154 Train-Acc:0.087 Test-Acc:0.098
# I:155 Train-Acc:0.087 Test-Acc:0.098
# I:156 Train-Acc:0.087 Test-Acc:0.098
# I:157 Train-Acc:0.087 Test-Acc:0.098
# I:158 Train-Acc:0.087 Test-Acc:0.098
# I:159 Train-Acc:0.087 Test-Acc:0.098
# I:160 Train-Acc:0.087 Test-Acc:0.098
# I:161 Train-Acc:0.087 Test-Acc:0.098
# I:162 Train-Acc:0.087 Test-Acc:0.098
# I:163 Train-Acc:0.087 Test-Acc:0.098
# I:164 Train-Acc:0.087 Test-Acc:0.098
# I:165 Train-Acc:0.087 Test-Acc:0.098
# I:166 Train-Acc:0.087 Test-Acc:0.098
# I:167 Train-Acc:0.087 Test-Acc:0.098
# I:168 Train-Acc:0.087 Test-Acc:0.098
# I:169 Train-Acc:0.087 Test-Acc:0.098
# I:170 Train-Acc:0.087 Test-Acc:0.098
# I:171 Train-Acc:0.087 Test-Acc:0.098
# I:172 Train-Acc:0.087 Test-Acc:0.098
# I:173 Train-Acc:0.087 Test-Acc:0.098
# I:174 Train-Acc:0.087 Test-Acc:0.098
# I:175 Train-Acc:0.087 Test-Acc:0.098
# I:176 Train-Acc:0.087 Test-Acc:0.098
# I:177 Train-Acc:0.087 Test-Acc:0.098
# I:178 Train-Acc:0.087 Test-Acc:0.098
# I:179 Train-Acc:0.087 Test-Acc:0.098
# I:180 Train-Acc:0.087 Test-Acc:0.098
# I:181 Train-Acc:0.087 Test-Acc:0.098
# I:182 Train-Acc:0.087 Test-Acc:0.098
# I:183 Train-Acc:0.087 Test-Acc:0.098
# I:184 Train-Acc:0.087 Test-Acc:0.098
# I:185 Train-Acc:0.087 Test-Acc:0.098
# I:186 Train-Acc:0.087 Test-Acc:0.098
# I:187 Train-Acc:0.087 Test-Acc:0.098
# I:188 Train-Acc:0.087 Test-Acc:0.098
# I:189 Train-Acc:0.087 Test-Acc:0.098
# I:190 Train-Acc:0.087 Test-Acc:0.098
# I:191 Train-Acc:0.087 Test-Acc:0.098
# I:192 Train-Acc:0.087 Test-Acc:0.098
# I:193 Train-Acc:0.087 Test-Acc:0.098
# I:194 Train-Acc:0.087 Test-Acc:0.098
# I:195 Train-Acc:0.087 Test-Acc:0.098
# I:196 Train-Acc:0.087 Test-Acc:0.098
# I:197 Train-Acc:0.087 Test-Acc:0.098
# I:198 Train-Acc:0.087 Test-Acc:0.098
# I:199 Train-Acc:0.087 Test-Acc:0.098
# I:200 Train-Acc:0.087 Test-Acc:0.098
# I:201 Train-Acc:0.087 Test-Acc:0.098
# I:202 Train-Acc:0.087 Test-Acc:0.098
# I:203 Train-Acc:0.087 Test-Acc:0.098
# I:204 Train-Acc:0.087 Test-Acc:0.098
# I:205 Train-Acc:0.087 Test-Acc:0.098
# I:206 Train-Acc:0.087 Test-Acc:0.098
# I:207 Train-Acc:0.087 Test-Acc:0.098
# I:208 Train-Acc:0.087 Test-Acc:0.098
# I:209 Train-Acc:0.087 Test-Acc:0.098
# I:210 Train-Acc:0.087 Test-Acc:0.098
# I:211 Train-Acc:0.087 Test-Acc:0.098
# I:212 Train-Acc:0.087 Test-Acc:0.098
# I:213 Train-Acc:0.087 Test-Acc:0.098
# I:214 Train-Acc:0.087 Test-Acc:0.098
# I:215 Train-Acc:0.087 Test-Acc:0.098
# I:216 Train-Acc:0.087 Test-Acc:0.098
# I:217 Train-Acc:0.087 Test-Acc:0.098
# I:218 Train-Acc:0.087 Test-Acc:0.098
# I:219 Train-Acc:0.087 Test-Acc:0.098
# I:220 Train-Acc:0.087 Test-Acc:0.098
# I:221 Train-Acc:0.087 Test-Acc:0.098
# I:222 Train-Acc:0.087 Test-Acc:0.098
# I:223 Train-Acc:0.087 Test-Acc:0.098
# I:224 Train-Acc:0.087 Test-Acc:0.098
# I:225 Train-Acc:0.087 Test-Acc:0.098
# I:226 Train-Acc:0.087 Test-Acc:0.098
# I:227 Train-Acc:0.087 Test-Acc:0.098
# I:228 Train-Acc:0.087 Test-Acc:0.098
# I:229 Train-Acc:0.087 Test-Acc:0.098
# I:230 Train-Acc:0.087 Test-Acc:0.098
# I:231 Train-Acc:0.087 Test-Acc:0.098
# I:232 Train-Acc:0.087 Test-Acc:0.098
# I:233 Train-Acc:0.087 Test-Acc:0.098
# I:234 Train-Acc:0.087 Test-Acc:0.098
# I:235 Train-Acc:0.087 Test-Acc:0.098
# I:236 Train-Acc:0.087 Test-Acc:0.098
# I:237 Train-Acc:0.087 Test-Acc:0.098
# I:238 Train-Acc:0.087 Test-Acc:0.098
# I:239 Train-Acc:0.087 Test-Acc:0.098
# I:240 Train-Acc:0.087 Test-Acc:0.098
# I:241 Train-Acc:0.087 Test-Acc:0.098
# I:242 Train-Acc:0.087 Test-Acc:0.098
# I:243 Train-Acc:0.087 Test-Acc:0.098
# I:244 Train-Acc:0.087 Test-Acc:0.098
# I:245 Train-Acc:0.087 Test-Acc:0.098
# I:246 Train-Acc:0.087 Test-Acc:0.098
# I:247 Train-Acc:0.087 Test-Acc:0.098
# I:248 Train-Acc:0.087 Test-Acc:0.098
# I:249 Train-Acc:0.087 Test-Acc:0.098
# I:250 Train-Acc:0.087 Test-Acc:0.098
# I:251 Train-Acc:0.087 Test-Acc:0.098
# I:252 Train-Acc:0.087 Test-Acc:0.098
# I:253 Train-Acc:0.087 Test-Acc:0.098
# I:254 Train-Acc:0.087 Test-Acc:0.098
# I:255 Train-Acc:0.087 Test-Acc:0.098
# I:256 Train-Acc:0.087 Test-Acc:0.098
# I:257 Train-Acc:0.087 Test-Acc:0.098
# I:258 Train-Acc:0.087 Test-Acc:0.098
# I:259 Train-Acc:0.087 Test-Acc:0.098
# I:260 Train-Acc:0.087 Test-Acc:0.098
# I:261 Train-Acc:0.087 Test-Acc:0.098
# I:262 Train-Acc:0.087 Test-Acc:0.098
# I:263 Train-Acc:0.087 Test-Acc:0.098
# I:264 Train-Acc:0.087 Test-Acc:0.098
# I:265 Train-Acc:0.087 Test-Acc:0.098
# I:266 Train-Acc:0.087 Test-Acc:0.098
# I:267 Train-Acc:0.087 Test-Acc:0.098
# I:268 Train-Acc:0.087 Test-Acc:0.098
# I:269 Train-Acc:0.087 Test-Acc:0.098
# I:270 Train-Acc:0.087 Test-Acc:0.098
# I:271 Train-Acc:0.087 Test-Acc:0.098
# I:272 Train-Acc:0.087 Test-Acc:0.098
# I:273 Train-Acc:0.087 Test-Acc:0.098
# I:274 Train-Acc:0.087 Test-Acc:0.098
# I:275 Train-Acc:0.087 Test-Acc:0.098
# I:276 Train-Acc:0.087 Test-Acc:0.098
# I:277 Train-Acc:0.087 Test-Acc:0.098
# I:278 Train-Acc:0.087 Test-Acc:0.098
# I:279 Train-Acc:0.087 Test-Acc:0.098
# I:280 Train-Acc:0.087 Test-Acc:0.098
# I:281 Train-Acc:0.087 Test-Acc:0.098
# I:282 Train-Acc:0.087 Test-Acc:0.098
# I:283 Train-Acc:0.087 Test-Acc:0.098
# I:284 Train-Acc:0.087 Test-Acc:0.098
# I:285 Train-Acc:0.087 Test-Acc:0.098
# I:286 Train-Acc:0.087 Test-Acc:0.098
# I:287 Train-Acc:0.087 Test-Acc:0.098
# I:288 Train-Acc:0.087 Test-Acc:0.098
# I:289 Train-Acc:0.087 Test-Acc:0.098
# I:290 Train-Acc:0.087 Test-Acc:0.098
# I:291 Train-Acc:0.087 Test-Acc:0.098
# I:292 Train-Acc:0.087 Test-Acc:0.098
# I:293 Train-Acc:0.087 Test-Acc:0.098
# I:294 Train-Acc:0.087 Test-Acc:0.098
# I:295 Train-Acc:0.087 Test-Acc:0.098
# I:296 Train-Acc:0.087 Test-Acc:0.098
# I:297 Train-Acc:0.087 Test-Acc:0.098
# I:298 Train-Acc:0.087 Test-Acc:0.098
# I:299 Train-Acc:0.087 Test-Acc:0.098
