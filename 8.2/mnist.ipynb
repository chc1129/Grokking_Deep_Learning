# %%
import sys, numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255,
                  y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images  = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

def relu(x):
    return (x > 0) * x

def relu2deriv(output):
    return output > 0

np.random.seed(1)
alpha, iterations, hidden_size = (0.005, 300, 40)
pixels_per_image, num_labels = (784, 10)

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

for j in range(iterations):
    train_err, train_acc = (0.0, 0)
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        train_err += np.sum((labels[i:i+1] - layer_2) ** 2)
        train_acc += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = \
            layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
        
    sys.stdout.write(
        "\r" + \
        " I:"+ str(j) + \
        " Train-Err:" + str(train_err/float(len(images)))[0:5] + \
        " Train-Acc:" + str(train_acc/float(len(images))))
# Out:
#  I:299 Train-Err:0.004 Train-Acc:0.999

# %%
if(j % 10 == 0 or j == iterations-1):
    test_err, test_acc = (0.0, 0)
    
    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        test_err += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
    sys.stdout.write(
        " Test-Err:" + str(test_err/float(len(test_images)))[0:5] + \
        " Test-Acc:" + str(test_acc/float(len(test_images))))
# Out:
#  Test-Err:0.351 Test-Acc:0.8316

# %%
import sys, numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255,
                  y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images  = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

np.random.seed(1)
relu = lambda x:(x>=0) * x # returns x if x > 0, return 0 otherwise
relu2deriv = lambda x: x>=0 # returns 1 for input > 0, return 0 otherwise
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 350, 40, 784, 10)

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

for j in range(iterations):
    train_err, train_acc = (0.0, 0)
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        train_err += np.sum((labels[i:i+1] - layer_2) ** 2)
        train_acc += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = \
            layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
        
    sys.stdout.write(
        "\r" + \
        " I:"+ str(j) + \
        " Train-Err:" + str(train_err/float(len(images)))[0:5] + \
        " Train-Acc:" + str(train_acc/float(len(images))))


    if(j % 10 == 0 or j == iterations-1):
        test_err, test_acc = (0.0, 0)
    
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            test_err += np.sum((test_labels[i:i+1] - layer_2) ** 2)
            test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
    sys.stdout.write(
        " Test-Err:" + str(test_err/float(len(test_images)))[0:5] + \
        " Test-Acc:" + str(test_acc/float(len(test_images))))
    
    print()
# Out:
#  I:0 Train-Err:0.722 Train-Acc:0.537 Test-Err:0.601 Test-Acc:0.6488
#  I:1 Train-Err:0.512 Train-Acc:0.753 Test-Err:0.601 Test-Acc:0.6488
#  I:2 Train-Err:0.448 Train-Acc:0.804 Test-Err:0.601 Test-Acc:0.6488
#  I:3 Train-Err:0.411 Train-Acc:0.837 Test-Err:0.601 Test-Acc:0.6488
#  I:4 Train-Err:0.385 Train-Acc:0.846 Test-Err:0.601 Test-Acc:0.6488
#  I:5 Train-Err:0.367 Train-Acc:0.863 Test-Err:0.601 Test-Acc:0.6488
#  I:6 Train-Err:0.352 Train-Acc:0.876 Test-Err:0.601 Test-Acc:0.6488
#  I:7 Train-Err:0.340 Train-Acc:0.884 Test-Err:0.601 Test-Acc:0.6488
#  I:8 Train-Err:0.329 Train-Acc:0.892 Test-Err:0.601 Test-Acc:0.6488
#  I:9 Train-Err:0.320 Train-Acc:0.897 Test-Err:0.601 Test-Acc:0.6488
#  I:10 Train-Err:0.312 Train-Acc:0.901 Test-Err:0.420 Test-Acc:0.8114
#  I:11 Train-Err:0.304 Train-Acc:0.904 Test-Err:0.420 Test-Acc:0.8114
#  I:12 Train-Err:0.297 Train-Acc:0.91 Test-Err:0.420 Test-Acc:0.8114
#  I:13 Train-Err:0.291 Train-Acc:0.914 Test-Err:0.420 Test-Acc:0.8114
#  I:14 Train-Err:0.286 Train-Acc:0.918 Test-Err:0.420 Test-Acc:0.8114
#  I:15 Train-Err:0.281 Train-Acc:0.918 Test-Err:0.420 Test-Acc:0.8114
#  I:16 Train-Err:0.276 Train-Acc:0.921 Test-Err:0.420 Test-Acc:0.8114
#  I:17 Train-Err:0.272 Train-Acc:0.922 Test-Err:0.420 Test-Acc:0.8114
#  I:18 Train-Err:0.268 Train-Acc:0.926 Test-Err:0.420 Test-Acc:0.8114
#  I:19 Train-Err:0.264 Train-Acc:0.927 Test-Err:0.420 Test-Acc:0.8114
#  I:20 Train-Err:0.260 Train-Acc:0.93 Test-Err:0.414 Test-Acc:0.8111
#  I:21 Train-Err:0.257 Train-Acc:0.932 Test-Err:0.414 Test-Acc:0.8111
#  I:22 Train-Err:0.254 Train-Acc:0.933 Test-Err:0.414 Test-Acc:0.8111
#  I:23 Train-Err:0.250 Train-Acc:0.935 Test-Err:0.414 Test-Acc:0.8111
#  I:24 Train-Err:0.247 Train-Acc:0.935 Test-Err:0.414 Test-Acc:0.8111
#  I:25 Train-Err:0.245 Train-Acc:0.939 Test-Err:0.414 Test-Acc:0.8111
#  I:26 Train-Err:0.242 Train-Acc:0.941 Test-Err:0.414 Test-Acc:0.8111
#  I:27 Train-Err:0.239 Train-Acc:0.941 Test-Err:0.414 Test-Acc:0.8111
#  I:28 Train-Err:0.237 Train-Acc:0.941 Test-Err:0.414 Test-Acc:0.8111
#  I:29 Train-Err:0.235 Train-Acc:0.945 Test-Err:0.414 Test-Acc:0.8111
#  I:30 Train-Err:0.232 Train-Acc:0.946 Test-Err:0.417 Test-Acc:0.8066
#  I:31 Train-Err:0.230 Train-Acc:0.947 Test-Err:0.417 Test-Acc:0.8066
#  I:32 Train-Err:0.228 Train-Acc:0.947 Test-Err:0.417 Test-Acc:0.8066
#  I:33 Train-Err:0.227 Train-Acc:0.948 Test-Err:0.417 Test-Acc:0.8066
#  I:34 Train-Err:0.225 Train-Acc:0.949 Test-Err:0.417 Test-Acc:0.8066
#  I:35 Train-Err:0.223 Train-Acc:0.953 Test-Err:0.417 Test-Acc:0.8066
#  I:36 Train-Err:0.221 Train-Acc:0.953 Test-Err:0.417 Test-Acc:0.8066
#  I:37 Train-Err:0.220 Train-Acc:0.955 Test-Err:0.417 Test-Acc:0.8066
#  I:38 Train-Err:0.218 Train-Acc:0.956 Test-Err:0.417 Test-Acc:0.8066
#  I:39 Train-Err:0.217 Train-Acc:0.956 Test-Err:0.417 Test-Acc:0.8066
#  I:40 Train-Err:0.215 Train-Acc:0.956 Test-Err:0.426 Test-Acc:0.8019
#  I:41 Train-Err:0.214 Train-Acc:0.958 Test-Err:0.426 Test-Acc:0.8019
#  I:42 Train-Err:0.213 Train-Acc:0.958 Test-Err:0.426 Test-Acc:0.8019
#  I:43 Train-Err:0.212 Train-Acc:0.96 Test-Err:0.426 Test-Acc:0.8019
#  I:44 Train-Err:0.210 Train-Acc:0.961 Test-Err:0.426 Test-Acc:0.8019
#  I:45 Train-Err:0.209 Train-Acc:0.963 Test-Err:0.426 Test-Acc:0.8019
#  I:46 Train-Err:0.208 Train-Acc:0.963 Test-Err:0.426 Test-Acc:0.8019
#  I:47 Train-Err:0.207 Train-Acc:0.963 Test-Err:0.426 Test-Acc:0.8019
#  I:48 Train-Err:0.206 Train-Acc:0.965 Test-Err:0.426 Test-Acc:0.8019
#  I:49 Train-Err:0.205 Train-Acc:0.966 Test-Err:0.426 Test-Acc:0.8019
#  I:50 Train-Err:0.204 Train-Acc:0.966 Test-Err:0.437 Test-Acc:0.7982
#  I:51 Train-Err:0.203 Train-Acc:0.966 Test-Err:0.437 Test-Acc:0.7982
#  I:52 Train-Err:0.202 Train-Acc:0.966 Test-Err:0.437 Test-Acc:0.7982
#  I:53 Train-Err:0.201 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:54 Train-Err:0.200 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:55 Train-Err:0.199 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:56 Train-Err:0.198 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:57 Train-Err:0.197 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:58 Train-Err:0.196 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:59 Train-Err:0.195 Train-Acc:0.967 Test-Err:0.437 Test-Acc:0.7982
#  I:60 Train-Err:0.194 Train-Acc:0.967 Test-Err:0.448 Test-Acc:0.7921
#  I:61 Train-Err:0.193 Train-Acc:0.968 Test-Err:0.448 Test-Acc:0.7921
#  I:62 Train-Err:0.193 Train-Acc:0.97 Test-Err:0.448 Test-Acc:0.7921
#  I:63 Train-Err:0.192 Train-Acc:0.97 Test-Err:0.448 Test-Acc:0.7921
#  I:64 Train-Err:0.191 Train-Acc:0.971 Test-Err:0.448 Test-Acc:0.7921
#  I:65 Train-Err:0.190 Train-Acc:0.972 Test-Err:0.448 Test-Acc:0.7921
#  I:66 Train-Err:0.189 Train-Acc:0.972 Test-Err:0.448 Test-Acc:0.7921
#  I:67 Train-Err:0.189 Train-Acc:0.974 Test-Err:0.448 Test-Acc:0.7921
#  I:68 Train-Err:0.188 Train-Acc:0.974 Test-Err:0.448 Test-Acc:0.7921
#  I:69 Train-Err:0.187 Train-Acc:0.974 Test-Err:0.448 Test-Acc:0.7921
#  I:70 Train-Err:0.186 Train-Acc:0.975 Test-Err:0.458 Test-Acc:0.7864
#  I:71 Train-Err:0.186 Train-Acc:0.975 Test-Err:0.458 Test-Acc:0.7864
#  I:72 Train-Err:0.185 Train-Acc:0.976 Test-Err:0.458 Test-Acc:0.7864
#  I:73 Train-Err:0.184 Train-Acc:0.976 Test-Err:0.458 Test-Acc:0.7864
#  I:74 Train-Err:0.183 Train-Acc:0.976 Test-Err:0.458 Test-Acc:0.7864
#  I:75 Train-Err:0.183 Train-Acc:0.977 Test-Err:0.458 Test-Acc:0.7864
#  I:76 Train-Err:0.182 Train-Acc:0.978 Test-Err:0.458 Test-Acc:0.7864
#  I:77 Train-Err:0.181 Train-Acc:0.978 Test-Err:0.458 Test-Acc:0.7864
#  I:78 Train-Err:0.180 Train-Acc:0.978 Test-Err:0.458 Test-Acc:0.7864
#  I:79 Train-Err:0.180 Train-Acc:0.979 Test-Err:0.458 Test-Acc:0.7864
#  I:80 Train-Err:0.179 Train-Acc:0.979 Test-Err:0.466 Test-Acc:0.7817
#  I:81 Train-Err:0.178 Train-Acc:0.979 Test-Err:0.466 Test-Acc:0.7817
#  I:82 Train-Err:0.178 Train-Acc:0.979 Test-Err:0.466 Test-Acc:0.7817
#  I:83 Train-Err:0.177 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:84 Train-Err:0.176 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:85 Train-Err:0.176 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:86 Train-Err:0.175 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:87 Train-Err:0.174 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:88 Train-Err:0.174 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:89 Train-Err:0.173 Train-Acc:0.98 Test-Err:0.466 Test-Acc:0.7817
#  I:90 Train-Err:0.172 Train-Acc:0.981 Test-Err:0.474 Test-Acc:0.7758
#  I:91 Train-Err:0.172 Train-Acc:0.981 Test-Err:0.474 Test-Acc:0.7758
#  I:92 Train-Err:0.171 Train-Acc:0.981 Test-Err:0.474 Test-Acc:0.7758
#  I:93 Train-Err:0.170 Train-Acc:0.981 Test-Err:0.474 Test-Acc:0.7758
#  I:94 Train-Err:0.170 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:95 Train-Err:0.169 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:96 Train-Err:0.169 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:97 Train-Err:0.168 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:98 Train-Err:0.167 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:99 Train-Err:0.167 Train-Acc:0.983 Test-Err:0.474 Test-Acc:0.7758
#  I:100 Train-Err:0.166 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:101 Train-Err:0.166 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:102 Train-Err:0.165 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:103 Train-Err:0.165 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:104 Train-Err:0.164 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:105 Train-Err:0.164 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:106 Train-Err:0.163 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:107 Train-Err:0.163 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:108 Train-Err:0.162 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:109 Train-Err:0.162 Train-Acc:0.984 Test-Err:0.482 Test-Acc:0.7706
#  I:110 Train-Err:0.161 Train-Acc:0.984 Test-Err:0.489 Test-Acc:0.7686
#  I:111 Train-Err:0.161 Train-Acc:0.984 Test-Err:0.489 Test-Acc:0.7686
#  I:112 Train-Err:0.161 Train-Acc:0.985 Test-Err:0.489 Test-Acc:0.7686
#  I:113 Train-Err:0.160 Train-Acc:0.985 Test-Err:0.489 Test-Acc:0.7686
#  I:114 Train-Err:0.160 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:115 Train-Err:0.159 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:116 Train-Err:0.159 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:117 Train-Err:0.158 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:118 Train-Err:0.158 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:119 Train-Err:0.158 Train-Acc:0.986 Test-Err:0.489 Test-Acc:0.7686
#  I:120 Train-Err:0.157 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:121 Train-Err:0.157 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:122 Train-Err:0.156 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:123 Train-Err:0.156 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:124 Train-Err:0.155 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:125 Train-Err:0.155 Train-Acc:0.987 Test-Err:0.496 Test-Acc:0.766
#  I:126 Train-Err:0.155 Train-Acc:0.986 Test-Err:0.496 Test-Acc:0.766
#  I:127 Train-Err:0.154 Train-Acc:0.987 Test-Err:0.496 Test-Acc:0.766
#  I:128 Train-Err:0.154 Train-Acc:0.988 Test-Err:0.496 Test-Acc:0.766
#  I:129 Train-Err:0.153 Train-Acc:0.989 Test-Err:0.496 Test-Acc:0.766
#  I:130 Train-Err:0.153 Train-Acc:0.99 Test-Err:0.502 Test-Acc:0.7622
#  I:131 Train-Err:0.153 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:132 Train-Err:0.152 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:133 Train-Err:0.152 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:134 Train-Err:0.151 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:135 Train-Err:0.151 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:136 Train-Err:0.151 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:137 Train-Err:0.150 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:138 Train-Err:0.150 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:139 Train-Err:0.149 Train-Acc:0.991 Test-Err:0.502 Test-Acc:0.7622
#  I:140 Train-Err:0.149 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:141 Train-Err:0.148 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:142 Train-Err:0.148 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:143 Train-Err:0.148 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:144 Train-Err:0.147 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:145 Train-Err:0.147 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:146 Train-Err:0.147 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:147 Train-Err:0.146 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:148 Train-Err:0.146 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:149 Train-Err:0.145 Train-Acc:0.991 Test-Err:0.508 Test-Acc:0.758
#  I:150 Train-Err:0.145 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:151 Train-Err:0.145 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:152 Train-Err:0.144 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:153 Train-Err:0.144 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:154 Train-Err:0.143 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:155 Train-Err:0.143 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:156 Train-Err:0.143 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:157 Train-Err:0.142 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:158 Train-Err:0.142 Train-Acc:0.991 Test-Err:0.513 Test-Acc:0.7558
#  I:159 Train-Err:0.142 Train-Acc:0.992 Test-Err:0.513 Test-Acc:0.7558
#  I:160 Train-Err:0.141 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:161 Train-Err:0.141 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:162 Train-Err:0.141 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:163 Train-Err:0.140 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:164 Train-Err:0.140 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:165 Train-Err:0.140 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:166 Train-Err:0.139 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:167 Train-Err:0.139 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:168 Train-Err:0.139 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:169 Train-Err:0.138 Train-Acc:0.992 Test-Err:0.518 Test-Acc:0.7553
#  I:170 Train-Err:0.138 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:171 Train-Err:0.138 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:172 Train-Err:0.137 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:173 Train-Err:0.137 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:174 Train-Err:0.137 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:175 Train-Err:0.137 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:176 Train-Err:0.136 Train-Acc:0.992 Test-Err:0.524 Test-Acc:0.751
#  I:177 Train-Err:0.136 Train-Acc:0.993 Test-Err:0.524 Test-Acc:0.751
#  I:178 Train-Err:0.136 Train-Acc:0.993 Test-Err:0.524 Test-Acc:0.751
#  I:179 Train-Err:0.135 Train-Acc:0.994 Test-Err:0.524 Test-Acc:0.751
#  I:180 Train-Err:0.135 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:181 Train-Err:0.135 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:182 Train-Err:0.135 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:183 Train-Err:0.134 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:184 Train-Err:0.134 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:185 Train-Err:0.134 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:186 Train-Err:0.133 Train-Acc:0.996 Test-Err:0.528 Test-Acc:0.7505
#  I:187 Train-Err:0.133 Train-Acc:0.996 Test-Err:0.528 Test-Acc:0.7505
#  I:188 Train-Err:0.133 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:189 Train-Err:0.133 Train-Acc:0.995 Test-Err:0.528 Test-Acc:0.7505
#  I:190 Train-Err:0.132 Train-Acc:0.995 Test-Err:0.533 Test-Acc:0.7482
#  I:191 Train-Err:0.132 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:192 Train-Err:0.132 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:193 Train-Err:0.132 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:194 Train-Err:0.131 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:195 Train-Err:0.131 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:196 Train-Err:0.131 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:197 Train-Err:0.130 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:198 Train-Err:0.130 Train-Acc:0.996 Test-Err:0.533 Test-Acc:0.7482
#  I:199 Train-Err:0.130 Train-Acc:0.998 Test-Err:0.533 Test-Acc:0.7482
#  I:200 Train-Err:0.130 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:201 Train-Err:0.129 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:202 Train-Err:0.129 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:203 Train-Err:0.129 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:204 Train-Err:0.129 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:205 Train-Err:0.128 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:206 Train-Err:0.128 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:207 Train-Err:0.128 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:208 Train-Err:0.128 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:209 Train-Err:0.127 Train-Acc:0.998 Test-Err:0.538 Test-Acc:0.7464
#  I:210 Train-Err:0.127 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:211 Train-Err:0.127 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:212 Train-Err:0.127 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:213 Train-Err:0.127 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:214 Train-Err:0.126 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:215 Train-Err:0.126 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:216 Train-Err:0.126 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:217 Train-Err:0.126 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:218 Train-Err:0.125 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:219 Train-Err:0.125 Train-Acc:0.998 Test-Err:0.544 Test-Acc:0.7446
#  I:220 Train-Err:0.125 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:221 Train-Err:0.125 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:222 Train-Err:0.125 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:223 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:224 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:225 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:226 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:227 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:228 Train-Err:0.124 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:229 Train-Err:0.123 Train-Acc:0.998 Test-Err:0.552 Test-Acc:0.7416
#  I:230 Train-Err:0.123 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:231 Train-Err:0.123 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:232 Train-Err:0.123 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:233 Train-Err:0.123 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:234 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:235 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:236 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:237 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:238 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:239 Train-Err:0.122 Train-Acc:0.998 Test-Err:0.560 Test-Acc:0.7372
#  I:240 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:241 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:242 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:243 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:244 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:245 Train-Err:0.121 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:246 Train-Err:0.120 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:247 Train-Err:0.120 Train-Acc:0.998 Test-Err:0.569 Test-Acc:0.7344
#  I:248 Train-Err:0.120 Train-Acc:0.999 Test-Err:0.569 Test-Acc:0.7344
#  I:249 Train-Err:0.120 Train-Acc:0.999 Test-Err:0.569 Test-Acc:0.7344
#  I:250 Train-Err:0.120 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:251 Train-Err:0.120 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:252 Train-Err:0.120 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:253 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:254 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:255 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:256 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:257 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:258 Train-Err:0.119 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:259 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.577 Test-Acc:0.7316
#  I:260 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:261 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:262 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:263 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:264 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:265 Train-Err:0.118 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:266 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:267 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:268 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:269 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.585 Test-Acc:0.729
#  I:270 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:271 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:272 Train-Err:0.117 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:273 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:274 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:275 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:276 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:277 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:278 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:279 Train-Err:0.116 Train-Acc:0.999 Test-Err:0.593 Test-Acc:0.7259
#  I:280 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:281 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:282 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:283 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:284 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:285 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:286 Train-Err:0.115 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:287 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:288 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:289 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.600 Test-Acc:0.723
#  I:290 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:291 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:292 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:293 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:294 Train-Err:0.114 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:295 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:296 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:297 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:298 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:299 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.607 Test-Acc:0.7196
#  I:300 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:301 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:302 Train-Err:0.113 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:303 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:304 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:305 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:306 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:307 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:308 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:309 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.614 Test-Acc:0.7183
#  I:310 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:311 Train-Err:0.112 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:312 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:313 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:314 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:315 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:316 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:317 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:318 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:319 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.622 Test-Acc:0.7165
#  I:320 Train-Err:0.111 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:321 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:322 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:323 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:324 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:325 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:326 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:327 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:328 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:329 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.629 Test-Acc:0.7133
#  I:330 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.637 Test-Acc:0.7125
#  I:331 Train-Err:0.110 Train-Acc:0.999 Test-Err:0.637 Test-Acc:0.7125
#  I:332 Train-Err:0.109 Train-Acc:0.999 Test-Err:0.637 Test-Acc:0.7125
#  I:333 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:334 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:335 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:336 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:337 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:338 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:339 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.637 Test-Acc:0.7125
#  I:340 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:341 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:342 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:343 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:344 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:345 Train-Err:0.109 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:346 Train-Err:0.108 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:347 Train-Err:0.108 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:348 Train-Err:0.108 Train-Acc:1.0 Test-Err:0.645 Test-Acc:0.71
#  I:349 Train-Err:0.108 Train-Acc:1.0 Test-Err:0.653 Test-Acc:0.7073

# %%
i = 0
layer_0 = images[i:i+1]
layer_1 = relu(np.dot(layer_0, weights_0_1))
dropout_mask = np.random.randint(2, size=layer_1.shape)
layer_1 *= dropout_mask * 2
layer_2 = np.dot(layer_1, weights_1_2)

train_err += np.sum((labels[i:i+1] - layer_2) ** 2)
train_acc += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))

layer_2_delta = (labels[i:i+1] - layer_2)
layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
layer_1_delta += dropout_mask

weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
